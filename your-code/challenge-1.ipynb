# %% [markdown]
# # Challenge 1 - T-test
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_re`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
from scipy import stats #scipy.stats cointains t-test funtions

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.).

# %%
# Your code here:
pokemon = pd.read_csv('Pokemon.csv')

# visiaulicing the first rows to understand the structure
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # iterate over each features(HP,Attack, Denfese...)

    for feature in features:
        t_stat,p_value = stats.ttest_ind(s1[feature],s2[feature])

        #gone to store the feature as the key and the p-value as the value.

        results[feature] = p_value
        
    
    return results

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
# Your code here
#we are gonna to separate the data frame into two groups depending on whter they are Legendary or not.
#H0:  There no significat difference between the stats of Legendary and non- Legendary
# H1 : There IS a significant diffence.

legendary = pokemon [pokemon['Legendary'] == True]
non_legendary = pokemon [pokemon['Legendary'] == False]

# llamaos a la funcion pasandole los dos grupos
legendary_results = t_test_features ( legendary, non_legendary)

# mostramos resultado

legendary_results
# Out:
# {'HP': np.float64(3.3306476848461913e-15),
#  'Attack': np.float64(7.827253003205333e-24),
#  'Defense': np.float64(1.5842226094427255e-12),
#  'Sp. Atk': np.float64(6.314915770427265e-41),
#  'Sp. Def': np.float64(1.8439809580409597e-26),
#  'Speed': np.float64(2.3540754436898437e-21),
#  'Total': np.float64(3.0952457469652825e-52)}

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here

print(" Feautures with significant diffence (p<0.05)")

for feature, p_value in legendary_results.items():
    if p_value < 0.05:
        significative = "✅ "
    else:
        significative= "❌ NO"

print(f"  {feature}: p={p_value:.2e} → {significative}")

#p-value es la probalidad del error Es la respuesta a: "¿Qué tan probable es que yo esté equivocado al decir que son diferentes?".
# Out:
#  Feautures with significant diffence (p<0.05)
#   Total: p=3.10e-52 → ✅

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here

generation1= pokemon[pokemon['Generation']==1]
generation2 = pokemon[pokemon['Generation']==2]

generation_result = t_test_features (generation1, generation2)

generation_result
# Out:
# {'HP': np.float64(0.13791881412813622),
#  'Attack': np.float64(0.24050968418101448),
#  'Defense': np.float64(0.5407630349194362),
#  'Sp. Atk': np.float64(0.14119788176331508),
#  'Sp. Def': np.float64(0.1678122623160639),
#  'Speed': np.float64(0.0028356954812578704),
#  'Total': np.float64(0.5599140649014442)}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here

print(" Feautures with significant diffence (p<0.05)")

for feature, p_value in generation_result.items():
    if p_value < 0.05:
        significative = "✅ "
    else:
        significative= "❌ NO"

print(f"  {feature}: p={p_value:.2e} → {significative}")

#No rechazamos la HO para la mayoria de features
# Out:
#  Feautures with significant diffence (p<0.05)
#   Total: p=5.60e-01 → ❌ NO

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
# Your code here

# a pokemon is a single type if Type 2 is NaN(empty)
# a pokemon is dualtype if it has a value in Type 2
# HO: tHERE IS NO difference between single-type and dual- type pokemon
#H1 : tHERE IS DIFERRENCE 

dual_type = pokemon[pokemon['Type 2']. notna()]

single_type =  pokemon[pokemon['Type 2']. isna()]

print(f" single_type  : {len(single_type )} pokemon")

print (f" dual_type  : {len(dual_type )} pokemon")

#  con la funcion ( t_test_features) comprovamos si su estadisticas( ataque, defensa.. son superiores
type_results =  t_test_features(single_type, dual_type)


type_results

# Recuerda que el P-value solo dice la diferencia si es gigante

# Miramos el promedio de fuerza de cada uno
mean_single = single_type['Total'].mean()
mean_dual = dual_type['Total'].mean()

print(f"Mean Single: {mean_single}")
print(f"Mean Dual: {mean_dual}")

print(pokemon.columns)
# Out:
#  single_type  : 386 pokemon
#  dual_type  : 414 pokemon
# Mean Single: 412.01554404145077
# Mean Dual: 456.6280193236715
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
print("Features with diffrence significative (p <0.05) :")

for feature, p_value in type_results.items():
  if p_value < 0.05:
        significative = "✅ "
  else:
        significative= "❌ NO"

        # la f permite meter variables dentro del texto usando llaves{}
        
        print(f" {feature} : p ={p_value :.4f} {significative}")
# Out:
# Features with diffrence significative (p <0.05) :
#  HP : p =0.1106 ❌ NO

# %%
#Cientificamente , aceptamos que no hay difrencia real en la salud (HP) entre Pokemon de uno o dos tipos

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here
# H0_1 :there is no difference between Attack and Defense for all Pokémon
#H0_2: There no difrerence between Special Attack and Special Defense for all Pokémon


#Attack vs Defense
t_atk,p_atk =stats.ttest_rel(pokemon['Attack'], pokemon['Defense'])
print (f" Attack vs Defense : t = {t_atk :.4f}, p = {p_atk:.4f}")


# Sp. Atk vs Sp. Def
t_spatk_spdef, p_spatk_spdef = stats.ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])
print(f"Sp. Atk vs Sp. Def:  t={t_spatk_spdef:.4f}, p={p_spatk_spdef:.4f}")
# Out:
#  Attack vs Defense : t = 4.3256, p = 0.0000
# Sp. Atk vs Sp. Def:  t=0.8540, p=0.3934

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
print ("Attack vd Defense")

if p_atk < 0.005:
    significative : "  ❌ Reject H0"
else:
    significative : "  ✅ Accept H0"

print(f"  p={p_atk:.4f} → {significative}")
# Out:
# Attack vd Defense
#   p=0.0000 → ✅

# %%
# For second  ( # Sp. Atk vs Sp. Def)

if p_spatk_spdef < 0.05:
    conclusion_2 = "✅ Reject H0"
else:
    conclusion_2 = "❌ Accept H0"

print(f"  p={p_spatk_spdef:.4f} → {conclusion_2}")
# Out:
#   p=0.3934 → ❌ Accept H0
